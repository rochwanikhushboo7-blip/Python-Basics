# %%
tup_1 = ('a','b','c')
t_1st = list(tup_1)
print(t_1st)

t_1st.append('d')
print(t_1st)

List = tuple(t_1st)
print(t_1st)
# Out:
# ['a', 'b', 'c']
# ['a', 'b', 'c', 'd']
# ['a', 'b', 'c', 'd']

# %%
stud = ['garima','khushboo','khushboo','kanak']
un_stud = set(stud)
print(un_stud)
l_d = list(un_stud)
print(l_d)
# Out:
# {'garima', 'khushboo', 'kanak'}
# ['garima', 'khushboo', 'kanak']

# %%
list A = [x for ]
