# %%
x=45
print(x)
print(type(x))
# Out:
# 45
# <class 'int'>

# %%
fruits=["apple","bananas","kiwi","coconut","walnut","guava","peach"]
fruits.append("strawberry")
fruits.append("orange")
fruits.append("grapes")
print(fruits)
fruits.remove("walnut")
fruits
fruits.extend(["cherry","abxc","ghy"])
print(fruits)
fruits.append([1,2,3])
print(fruits)
fruits.pop()
print(fruits)
# Out:
# ['apple', 'bananas', 'kiwi', 'coconut', 'walnut', 'guava', 'peach', 'strawberry', 'orange', 'grapes']
# ['apple', 'bananas', 'kiwi', 'coconut', 'guava', 'peach', 'strawberry', 'orange', 'grapes', 'cherry', 'abxc', 'ghy']
# ['apple', 'bananas', 'kiwi', 'coconut', 'guava', 'peach', 'strawberry', 'orange', 'grapes', 'cherry', 'abxc', 'ghy', [1, 2, 3]]
# ['apple', 'bananas', 'kiwi', 'coconut', 'guava', 'peach', 'strawberry', 'orange', 'grapes', 'cherry', 'abxc', 'ghy']
