# %%
k_1 = "250"
p_1 = int(k_1)
p_1
# Out:
# 250

# %%
p = 99
print(type(p))
k_1 = float(p)
print(k_1)

ak_2 = str(p)
ak_2
# Out:
# <class 'int'>
# 99.0
# '99'

# %%
x ="45.67"
s_1 = float(x)
print(s_1)
x_2 = str(x)
x_2
# Out:
# 45.67
# '45.67'
